# %%
"""
Created 2022

@author: Morten Haubro
@contributors: Morten Haubro, Asmus Ougaard Dohn, Philipp Lenzen
"""

# %% [markdown]
# # Example notebook for XSS data analysis
# - Assumes that the first Data reduction script has run and calculating diffs have run
# - In general the output files are compatible with the lcls Scan class, available in the git and on maxwell

# %%
# %load_ext autoreload
# %autoreload 2
from power_titration import power_titration
from lcls import Scan
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# A couple of examples on how to use the Scan class, for plotting and svd

# %%
scan = Scan('../Diffs/Run104_Reduced.mat')
scan.plot_2d(scan.time,scan.q,scan.atd_az)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1a51af60888>,
#  <matplotlib.colorbar.Colorbar at 0x1a51b19f788>)

# %%
scan.plot_lineseries(scan.atd_az)
ax = plt.gca()

# %%
spectraces, vals, timetraces = scan.plot_svd(scan.q, scan.time, scan.atd_az, showplot=True,shift_fac=0.0001)

# %% [markdown]
# power titrations can be performed with the function below, just input relevant run numbers and corresponding powers, the output is an average over all time delays in each run

# %%
powers = [30,40,70]
runs = [104,104,104]
power_titration(runs,powers)
